# %%
import pandas as pd
import pyarrow as pv
import os
from google.cloud import storage
# Only need this if you're running this code locally.
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'../.google/credentials/google_credentials.json'

# %%
client = storage.Client()
bucket_dtc = client.get_bucket('dtc_data_lake_de-zoomcamp-356807')
bucket_nyc = client.get_bucket('nyc-tlc-backup')

# %%
df = pd.read_csv("gs://nyc-tlc-backup/yellow_tripdata_2019-01.csv", encoding = "ISO-8859-1",low_memory=False)
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...           ...                  ...                   ...              ...
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
# 7667788         2  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789         2  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790         2  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791         2  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
# ...

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
a = df['VendorID'].unique()                    
b = df['tpep_pickup_datetime'].unique()      
c = df['tpep_dropoff_datetime'].unique()     
d = df['passenger_count'].unique()        
e = df['trip_distance'].unique()                 
f = df['RatecodeID'].unique()               
g = df['store_and_fwd_flag'].unique()               
h = df['PULocationID'].unique()            
i = df['DOLocationID'].unique()            
j = df['payment_type'].unique()              
k = df['fare_amount'].unique()                    
l = df['extra'].unique()                  
m = df['mta_tax'].unique()               
n = df['tip_amount'].unique()             
o = df['tolls_amount'].unique()                
p = df['improvement_surcharge'].unique()    
q = df['total_amount'].unique()             
r = df['congestion_surcharge'].unique()

# %%
print('VendorID',a)
print('tpep_pickup_datetime',b)
print('tpep_dropoff_datetime',c)
print('passenger_count',d)
print('trip_distance',e)
print('RatecodeID',f)
print('store_and_fwd_flag',g)
print('PULocationID',h)
print('DOLocationID',i)
print('payment_type',j)
print('fare_amount',k)
print('extra',l)
print('mta_tax',m)
print('tip_amount',n)
print('tolls_amount',o)
print('improvement_surcharge',p)
print('total_amount',q)
print('congestion_surcharge',r)
# Out:
# VendorID [1 2 4]
# tpep_pickup_datetime ['2019-01-01 00:46:40' '2019-01-01 00:59:47' '2018-12-21 13:48:30' ...
#  '2019-01-31 23:57:53' '2019-01-31 23:58:38' '2019-01-31 23:54:41']
# tpep_dropoff_datetime ['2019-01-01 00:53:20' '2019-01-01 01:18:59' '2018-12-21 13:52:40' ...
#  '2019-02-01 00:16:18' '2019-02-01 00:30:41' '2019-02-01 00:18:39']
# passenger_count [1 3 5 2 4 0 6 8 7 9]
# trip_distance [ 1.5   2.6   0.   ... 29.63 33.12 44.81]
# RatecodeID [ 1  2  4  5  3 99  6]
# store_and_fwd_flag ['N' 'Y']
# PULocationID [151 239 236 193 163 229 141 246 238 224 170 107  41 116 113 161 138 144
#  231 237 263 132 264 142 249 137  90 162 140  68  88  74  79  75 233 148
#   48 143   4 164 232  45  43 186 158  50 114  42  14  11 181 211  13 261
#   97 234 125 145 262 226  24 166  80 189  33 100 126 159 244 243 209  87
#   25 260 223 196 152 230   7  66 228 235 265 134  65 129  82 195 255 179
#  169  89  37  17 225  12  52 112 256  61 257 215  70 217 177  49 168  76
# ...

# %%
df[['tpep_pickup_datetime','tpep_dropoff_datetime']] = df[['tpep_pickup_datetime','tpep_dropoff_datetime']].apply(pd.to_datetime, errors = 'coerce')

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object
